# %% [markdown]
# ## Exercício 1: Vestibular
#
# Considere que a os dados gerados na célula abaixo contêm o número de acertos de 100 alunos em um vestibular para um curso de exatas, divididas pelos respectivos assuntos. Considere que cada assunto possui um número de questões conforme a tabela abaixo:
#
# | assunto | número de questões |
# |:---:|:---:|
# | Matemática | 24 |
# | Português | 18 |
# | Geografia | 8 |
# | Inglês | 8 |
# | História | 8 |
# | Física | 12 |
# | Química | 12 |
#
# Usando os comandos de operações com DataFrames que você aprendeu na Aula 03, calcule:
#
# 1. (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.
# 2. (operações entre *DataFrames) Calcule o total de acertos de cada aluno.
# 3. Calcule o porcentual geral de cada aluno.
# 4. Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
import pandas as pd
import numpy as np

np.random.seed(42)
df_mat = pd.DataFrame(np.random.randint(24, size=(100, 1)), columns=['Qt_acertos'])

df_por = pd.DataFrame(np.random.randint(18, size=(100, 1)), columns=['Qt_acertos'])

df_geo = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_ing = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_his = pd.DataFrame(np.random.randint(8, size=(100, 1)), columns=['Qt_acertos'])

df_fis = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

df_qui = pd.DataFrame(np.random.randint(12, size=(100, 1)), columns=['Qt_acertos'])

# %%
df_mat
# Out:
#     Qt_acertos
# 0            6
# 1           19
# 2           14
# 3           10
# 4            7
# ..         ...
# 95           6
# 96           8
# 97          23
# 98           0
# 99          11
#
# [100 rows x 1 columns]

# %%
df_por
# Out:
#     Qt_acertos
# 0            7
# 1           10
# 2           16
# 3            7
# 4            2
# ..         ...
# 95           4
# 96           1
# 97           5
# 98          10
# 99          15
#
# [100 rows x 1 columns]

# %%
df_geo
# Out:
#     Qt_acertos
# 0            7
# 1            0
# 2            0
# 3            3
# 4            2
# ..         ...
# 95           7
# 96           4
# 97           0
# 98           3
# 99           0
#
# [100 rows x 1 columns]

# %%
df_ing
# Out:
#     Qt_acertos
# 0            3
# 1            0
# 2            5
# 3            4
# 4            7
# ..         ...
# 95           1
# 96           6
# 97           2
# 98           1
# 99           1
#
# [100 rows x 1 columns]

# %%
df_his
# Out:
#     Qt_acertos
# 0            1
# 1            0
# 2            7
# 3            0
# 4            0
# ..         ...
# 95           4
# 96           1
# 97           4
# 98           5
# 99           6
#
# [100 rows x 1 columns]

# %%
df_fis
# Out:
#     Qt_acertos
# 0            8
# 1           11
# 2            4
# 3            0
# 4            9
# ..         ...
# 95           9
# 96           4
# 97           1
# 98          10
# 99           7
#
# [100 rows x 1 columns]

# %%
df_qui
# Out:
#     Qt_acertos
# 0            3
# 1            8
# 2            4
# 3            8
# 4            3
# ..         ...
# 95           3
# 96           3
# 97           5
# 98          11
# 99           2
#
# [100 rows x 1 columns]

# %% [markdown]
# ### 1 - (operações com escalar) Calcule o percentual de acerto dos alunos por assunto.

# %%
perc_mat = df_mat / 24
perc_por = df_por / 18
perc_geo = df_geo /  8
perc_ing = df_ing /  8
perc_his = df_his /  8
perc_fis = df_fis / 12
perc_qui = df_qui / 12

# %%
perc_mat
# Out:
#     Qt_acertos
# 0     0.250000
# 1     0.791667
# 2     0.583333
# 3     0.416667
# 4     0.291667
# ..         ...
# 95    0.250000
# 96    0.333333
# 97    0.958333
# 98    0.000000
# 99    0.458333
#
# [100 rows x 1 columns]

# %%
perc_por
# Out:
#     Qt_acertos
# 0     0.388889
# 1     0.555556
# 2     0.888889
# 3     0.388889
# 4     0.111111
# ..         ...
# 95    0.222222
# 96    0.055556
# 97    0.277778
# 98    0.555556
# 99    0.833333
#
# [100 rows x 1 columns]

# %%
perc_geo
# Out:
#     Qt_acertos
# 0        0.875
# 1        0.000
# 2        0.000
# 3        0.375
# 4        0.250
# ..         ...
# 95       0.875
# 96       0.500
# 97       0.000
# 98       0.375
# 99       0.000
#
# [100 rows x 1 columns]

# %%
perc_ing
# Out:
#     Qt_acertos
# 0        0.375
# 1        0.000
# 2        0.625
# 3        0.500
# 4        0.875
# ..         ...
# 95       0.125
# 96       0.750
# 97       0.250
# 98       0.125
# 99       0.125
#
# [100 rows x 1 columns]

# %%
perc_his
# Out:
#     Qt_acertos
# 0        0.125
# 1        0.000
# 2        0.875
# 3        0.000
# 4        0.000
# ..         ...
# 95       0.500
# 96       0.125
# 97       0.500
# 98       0.625
# 99       0.750
#
# [100 rows x 1 columns]

# %%
perc_fis
# Out:
#     Qt_acertos
# 0     0.666667
# 1     0.916667
# 2     0.333333
# 3     0.000000
# 4     0.750000
# ..         ...
# 95    0.750000
# 96    0.333333
# 97    0.083333
# 98    0.833333
# 99    0.583333
#
# [100 rows x 1 columns]

# %%
perc_qui
# Out:
#     Qt_acertos
# 0     0.250000
# 1     0.666667
# 2     0.333333
# 3     0.666667
# 4     0.250000
# ..         ...
# 95    0.250000
# 96    0.250000
# 97    0.416667
# 98    0.916667
# 99    0.166667
#
# [100 rows x 1 columns]

# %% [markdown]
# ### 2 - (operações entre *DataFrames) Calcule o total de acertos de cada aluno.

# %%
total_ac = df_mat + df_por + df_geo + df_ing + df_his + df_fis + df_qui
total_ac
# Out:
#     Qt_acertos
# 0           35
# 1           48
# 2           50
# 3           32
# 4           30
# ..         ...
# 95          34
# 96          27
# 97          40
# 98          40
# 99          42
#
# [100 rows x 1 columns]

# %% [markdown]
# ###  3 - Calcule o porcentual geral de cada aluno.

# %%
perc_aluno = total_ac/90
perc_aluno
# Out:
#     Qt_acertos
# 0     0.388889
# 1     0.533333
# 2     0.555556
# 3     0.355556
# 4     0.333333
# ..         ...
# 95    0.377778
# 96    0.300000
# 97    0.444444
# 98    0.444444
# 99    0.466667
#
# [100 rows x 1 columns]

# %% [markdown]
# ### 4 - Suponha que a nota de corte para a segunda fase seja 45. Quantos alunos tiveram nota maior que 45?

# %%
nota_corte_45 = total_ac[total_ac['Qt_acertos'] > 45]
nota_corte_45.count()
# Out:
# Qt_acertos    31
# dtype: int64

# %% [markdown]
# ## 2) Vestibular II
#
# Ainda sobre o mesmo banco de dados:
#
# 1. Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo *DataFrame* com os alunos desqualificados por este critério.
# 2. Quantos são esses alunos?
# 3. Qual a média desses alunos em história e geografia?
# 4. Monte um *DataFrame* com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %% [markdown]
# ### <span style="color:blue"> 1 - Neste vestibular, quem 'zera' em matemática, física ou química está desqualificado. Monte um novo DataFrame com os alunos desqualificados por este critério.

# %%
df_eliminados_mat = total_ac[(df_mat['Qt_acertos'] == 0)]

# %%
df_aprovados_mat = total_ac[(df_mat['Qt_acertos'] != 0)]

# %%
df_eliminados_fis = total_ac[(df_fis['Qt_acertos'] == 0)]

# %%
df_aprovados_fis = total_ac[(df_fis['Qt_acertos'] != 0)]

# %%
df_eliminados_qui = total_ac[(df_qui['Qt_acertos'] == 0)]

# %%
df_aprovados_qui = total_ac[(df_qui['Qt_acertos'] != 0)]

# %%
#df_por  df_geo  df_ing  df_his

# %%
df_eliminados = total_ac[df_eliminados_mat + df_eliminados_fis  + df_eliminados_qui]

df_eliminados
# Out:
#     Qt_acertos
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 95         NaN
# 96         NaN
# 97         NaN
# 98         NaN
# 99         NaN
#
# [100 rows x 1 columns]

# %% [markdown]
# ### <span style="color:blue"> 2 - Quantos são esses alunos?

# %%
total_eliminados = df_eliminados.count()

total_eliminados

# %% [markdown]
# ### <span style="color:red"> 3 - Qual a média desses alunos em história e geografia?

# %%
#df_eliminados  

#media 

#df_his['Qt_acertos']
#df_geo['Qt_acertos']

# %% [markdown]
# ### <span style="color:red"> 4 - Monte um DataFrame com os alunos que passaram para a segunda fase. Repare que estes alunos não podem ter sido desqualificados.

# %% [markdown]
# ## 3) Vacinações no Acre
# Vamos trabalhar agora com a base de vacinações no Acre. Para facilitar a sua vida, copiamos o link do arquivo na célula abaixo.
#
# 1. Quantas vacinas estão registradas nessa base?
# 2. Quantos pacientes foram vacinados? (considere um paciente para cada valor único de ```paciente_id```)
# 3. Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método ```.unique()```.
# 4. Quantos pacientes com menos de 18 anos foram vacinados?
# 5. Quantos estabelecimentos aplicaram vacina no Acre?

# %%
arquivo = 'https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/PNI/vacina/uf/2021-05-23/uf%3DAC/part-00000-63e5bee2-3684-4286-b709-7fe85483b04e.c000.csv'

# %% [markdown]
# ### 1 - Quantas vacinas estão registradas nessa base?

# %%
df = pd.read_csv(arquivo, sep=';')

df
# Out:
#                                       document_id  \
# 0       b19cd280-474c-4c22-a35d-8c06bc04a4e0-i0b0
# 1       d7e13d32-32fb-4e9a-a559-b0bdd7929d2b-i0b0
# 2       af279a98-ba1f-47ea-8214-314a98040b0d-i0b0
# 3       22f523ac-3eb6-45b2-9f6e-4e9906f09b5a-i0b0
# 4       000e911b-e3a4-4114-a735-d1f2e6e3797f-i0b0
# ...                                           ...
# 174186  fbe546fd-1a90-4062-bd25-616051484d68-i0b0
# 174187  d182cfab-6d7e-4b09-b91a-e2015f86bfe4-i0b0
# 174188  fc9edd80-2383-4f9f-a018-61b9cb57b9ae-i0b0
# 174189  0c6c918f-655b-4c3f-906f-3b7301a69b67-i0b0
# 174190  d2bb586b-c050-4c11-a463-10b2cf9031e4-i0b0
#
#                                               paciente_id  paciente_idade  \
# 0       2e091c9a37d3f50d1d705fc80c6448c6fc69b44da9e936...              69
# 1       dd179041b80ce919ceffa504ad2eae6f9ac3d6bbdfd531...              63
# 2       6734b26bccf826130ebffa66575977bbe71477b12bcf42...              69
# ...

# %%
df.head()
# Out:
#                                  document_id  \
# 0  b19cd280-474c-4c22-a35d-8c06bc04a4e0-i0b0
# 1  d7e13d32-32fb-4e9a-a559-b0bdd7929d2b-i0b0
# 2  af279a98-ba1f-47ea-8214-314a98040b0d-i0b0
# 3  22f523ac-3eb6-45b2-9f6e-4e9906f09b5a-i0b0
# 4  000e911b-e3a4-4114-a735-d1f2e6e3797f-i0b0
#
#                                          paciente_id  paciente_idade  \
# 0  2e091c9a37d3f50d1d705fc80c6448c6fc69b44da9e936...              69
# 1  dd179041b80ce919ceffa504ad2eae6f9ac3d6bbdfd531...              63
# 2  6734b26bccf826130ebffa66575977bbe71477b12bcf42...              69
# 3  54dfc421baa6a03e54c8a57f08c50b0281d40659849fbc...              19
# 4  c59571e19f368d4b0cf08cd3bcabb32e5cd8baad5340f6...              65
#
#   paciente_datanascimento paciente_enumsexobiologico  paciente_racacor_codigo  \
# 0              1951-12-28                          F                        3
# 1              1957-06-09                          M                        3
# ...

# %%
df.shape[0]
# Out:
# 174191

# %% [markdown]
# ### 2 - Quantos pacientes foram vacinados? (considere um paciente para cada valor único de paciente_id)

# %%
df['paciente_id'].nunique()
# Out:
# 125009

# %% [markdown]
# ### 3 - Quantos pacientes únicos tomaram a primeira dose? OBS: Há um caractere especial neste campo. Receba os valores do campo com o método .unique().

# %%
primeira_dose = df['vacina_descricao_dose'].unique()[0]
df['paciente_id'].loc[df['vacina_descricao_dose'] == primeira_dose].nunique()
# Out:
# 124185

# %% [markdown]
# ### 4 - Quantos pacientes com menos de 18 anos foram vacinados?

# %%
df_menor = df[df["paciente_idade"]<18]
df_menor['paciente_id'].nunique()
# Out:
# 49

# %% [markdown]
# ### 5 - Quantos estabelecimentos aplicaram vacina no Acre?

# %%
df['estabelecimento_razaosocial'].nunique()
# Out:
# 42

# %% [markdown]
# ## 4) Vacinação II
# Gere um *DataFrame* que contenha somente os estabelecimentos que aplicaram vcinas a menores de 18 anos. Nesse *DataFrame* devem conter somente os dados dos estabelecimentos, mais uma coluna sendo a quantidade de vacinas que o estabelecimento aplicou a menores de 18 anos.
#
# 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.
# 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**
# 3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.
# 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.
# 4. usando o método *.loc*, selecione somente essas variáveis
# 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %% [markdown]
# ### 1. crie uma cópia do *DataFrame* original, contendo somente os registros de vacinas realizadas a menores de 18 anos.

# %%
df_menor = df[df["paciente_idade"]<18].copy()

df_menor
# Out:
#                                       document_id  \
# 1659    acd193a2-9d85-4861-abfc-c155f32bf7e8-i0b0
# 15757   fdb8d3b6-14d9-4bcc-9cfe-acd46b4a317a-i0b0
# 28570   449dcd9c-6404-42c2-9629-e6ccc6d1d186-i0b0
# 29435   6b414941-eea7-49b2-a1a5-5c618cd5a77b-i0b0
# 30514   5d97dc04-c9d8-4a83-9c7e-967a660b6c55-i0b0
# 34846   db3fad15-3688-484e-908e-2f0921c38dfc-i0b0
# 38026   b7431955-1faa-4c1e-9246-7c1e7b8bb3cb-i0b0
# 41025   45899bdb-6e8c-4f90-94c7-773d894f371b-i0b0
# 41169   6e2e5ea1-0aae-4e51-9129-45c78d012a93-i0b0
# 42189   7d9e37d4-27a8-4cba-bca7-0c1b2d0575fa-i0b0
# 46891   f0142540-1a3f-4882-ba3b-467d55f38dc0-i0b0
# 49016   0275a386-9165-410e-9e04-d20aa48190a5-i0b0
# 51142   1481a148-e03b-4205-82b5-17125fe42945-i0b0
# 52410   0ffb7fc2-f8cc-41fe-9646-d479628f6323-i0b0
# 59025   17276c54-f153-48a9-a03e-13ddf7d29e2a-i0b0
# 61676   000434aa-e1d1-4f2b-81de-7879fbaa458e-i0b0
# 66400   647e2301-3ba4-463a-8d1e-2b6f38a4d99e-i0b0
# 67140   1eb690de-c2aa-4c88-8943-29bd1019d0c4-i0b0
# ...

# %% [markdown]
# ### 2. crie uma lista das colunas desse *DataFrame* com o atributo de *DataFrame* **.columns()**

# %%
df_menor.columns
# Out:
# Index(['document_id', 'paciente_id', 'paciente_idade',
#        'paciente_datanascimento', 'paciente_enumsexobiologico',
#        'paciente_racacor_codigo', 'paciente_racacor_valor',
#        'paciente_endereco_coibgemunicipio', 'paciente_endereco_copais',
#        'paciente_endereco_nmmunicipio', 'paciente_endereco_nmpais',
#        'paciente_endereco_uf', 'paciente_endereco_cep',
#        'paciente_nacionalidade_enumnacionalidade', 'estabelecimento_valor',
#        'estabelecimento_razaosocial', 'estalecimento_nofantasia',
#        'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
#        'estabelecimento_uf', 'vacina_grupoatendimento_codigo',
#        'vacina_grupoatendimento_nome', 'vacina_categoria_codigo',
#        'vacina_categoria_nome', 'vacina_lote', 'vacina_fabricante_nome',
#        'vacina_fabricante_referencia', 'vacina_dataaplicacao',
#        'vacina_descricao_dose', 'vacina_codigo', 'vacina_nome',
# ...

# %% [markdown]
# ###  3. Nesse *DataFrame* faça uma contagem do campo ```vacina_categoria_nome```.

# %%
df_menor['vacina_categoria_nome'].value_counts()
# Out:
# Povos Indígenas                     33
# Trabalhadores de Saúde               9
# Povos e Comunidades Tradicionais     9
# Comorbidades                         2
# Faixa Etária                         1
# Name: vacina_categoria_nome, dtype: int64

# %% [markdown]
# ### 3. a partir da lista de colunas, escolha somente aquelas que são referentes ao estabelecimento, faça uma lista com esses valores.

# %%
lista_variaveis = ['estabelecimento_valor',
       'estabelecimento_razaosocial', 'estalecimento_nofantasia',
       'estabelecimento_municipio_codigo', 'estabelecimento_municipio_nome',
       'estabelecimento_uf']
# Out:
# ['estabelecimento_valor',
#  'estabelecimento_razaosocial',
#  'estalecimento_nofantasia',
#  'estabelecimento_municipio_codigo',
#  'estabelecimento_municipio_nome',
#  'estabelecimento_uf']

# %% [markdown]
# ### 4. usando o método *.loc*, selecione somente essas variáveis

# %%
df_menor_lista = df_menor.loc[:,lista_variaveis]

df_menor_lista
# Out:
#         estabelecimento_valor  \
# 1659                  2001748
# 15757                 6159087
# 28570                 6955525
# 29435                 6428940
# 30514                 7625855
# 34846                 6159087
# 38026                 6917291
# 41025                 6992811
# 41169                 6992811
# 42189                 6430201
# 46891                 9648968
# 49016                 6748759
# 51142                 7625855
# 52410                 6430201
# 59025                 6159087
# 61676                 6308740
# 66400                 2000040
# 67140                 7625855
# 68894                 6917682
# 69728                 6955525
# 71721                 7123043
# 77359                 6748759
# 81747                 6748759
# 82096                 5336171
# 83559                 6308740
# 85301                 2001748
# 88494                 7625855
# 89795                 2001314
# 100901                6697151
# 105718                6612385
# ...

# %% [markdown]
# ### 5. Aplique o método **.drop_duplicates** e crie uma lista com uma linha para cada estabelecimento, com os dados do estabelecimento

# %%
df_menor_lista = df_menor_lista.drop_duplicates()

df_menor_lista
# Out:
#         estabelecimento_valor  \
# 1659                  2001748
# 15757                 6159087
# 28570                 6955525
# 29435                 6428940
# 30514                 7625855
# 38026                 6917291
# 41025                 6992811
# 42189                 6430201
# 46891                 9648968
# 49016                 6748759
# 61676                 6308740
# 66400                 2000040
# 68894                 6917682
# 71721                 7123043
# 82096                 5336171
# 89795                 2001314
# 100901                6697151
# 105718                6612385
# 163788                3323307
#
#                               estabelecimento_razaosocial  \
# 1659                 PREFEITURA MUNICIPAL DE PORTO WALTER
# 15757             PREFEITURA MUNICIPAL DE CRUZEIRO DO SUL
# 28570   DISTRITO SANITARIO ESPECIAL INDIGENA ALTO RIO ...
# 29435                PREFEITURA MUNICIPAL DE ASSIS BRASIL
# ...

# %%
df_menor_lista.shape
# Out:
# (19, 6)
